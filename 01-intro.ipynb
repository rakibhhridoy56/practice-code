# %%
import pandas

# %%
pandas.__version__
# Out:
# '0.24.2'

# %%
df = pandas.read_csv('gapminder.tsv', sep='\t')

# %%
df = pandas.read_csv('../data/gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
# from pandas import * # don't do this

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country = df['country']

# %%
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
country = df[['country']]

# %%
country
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12        Albania
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# 21        Albania
# 22        Albania
# 23        Albania
# 24        Algeria
# 25        Algeria
# 26        Algeria
# 27        Algeria
# 28        Algeria
# 29        Algeria
# ...           ...
# 1674  Yemen, Rep.
# 1675  Yemen, Rep.
# 1676  Yemen, Rep.
# 1677  Yemen, Rep.
# 1678  Yemen, Rep.
# 1679  Yemen, Rep.
# 1680       Zambia
# 1681       Zambia
# 1682       Zambia
# 1683       Zambia
# 1684       Zambia
# 1685       Zambia
# 1686       Zambia
# 1687       Zambia
# 1688       Zambia
# 1689       Zambia
# 1690       Zambia
# 1691       Zambia
# ...

# %%
df_droped = df.drop(['continent', 'country'], axis='columns', )

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-c8e3ddd1947a> in <module>
# ----> 1 df.loc[-1]
#
# ...

# %%
df.iloc[[0, 1, -1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
subset = df.loc[:, ['year', 'pop']]

# %%
subset.head()
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
subset = df.iloc[:, [2, 4]]

# %%
subset.head()
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
df.loc[df['country'] == 'United States']
# Out:
#             country continent  year  lifeExp        pop    gdpPercap
# 1608  United States  Americas  1952   68.440  157553000  13990.48208
# 1609  United States  Americas  1957   69.490  171984000  14847.12712
# 1610  United States  Americas  1962   70.210  186538000  16173.14586
# 1611  United States  Americas  1967   70.760  198712000  19530.36557
# 1612  United States  Americas  1972   71.340  209896000  21806.03594
# 1613  United States  Americas  1977   73.380  220239000  24072.63213
# 1614  United States  Americas  1982   74.650  232187835  25009.55914
# 1615  United States  Americas  1987   75.020  242803533  29884.35041
# 1616  United States  Americas  1992   76.090  256894189  32003.93224
# 1617  United States  Americas  1997   76.810  272911760  35767.43303
# 1618  United States  Americas  2002   77.310  287675526  39097.09955
# 1619  United States  Americas  2007   78.242  301139947  42951.65309

# %%
df.loc[(df['country'] == 'United States') & (df['year'] == 1982)]
# Out:
#             country continent  year  lifeExp        pop    gdpPercap
# 1614  United States  Americas  1982    74.65  232187835  25009.55914

# %%
df.groupby(['year'])['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
import numpy as np
df.groupby(['year'])['lifeExp'].agg(np.std)
# Out:
# year
# 1952    12.225956
# 1957    12.231286
# 1962    12.097245
# 1967    11.718858
# 1972    11.381953
# 1977    11.227229
# 1982    10.770618
# 1987    10.556285
# 1992    11.227380
# 1997    11.559439
# 2002    12.279823
# 2007    12.073021
# Name: lifeExp, dtype: float64

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].agg(np.mean).reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %% [markdown]
# ## Exercise

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %%
df.values[853]
# Out:
# array(['Kuwait', 'Asia', 1957, 58.033, 212846, 113523.1329], dtype=object)

# %%
df['gdpPercap'].values.argmin()
# Out:
# 334

# %%
df.values[df['gdpPercap'].values.argmin()]
# Out:
# array(['Congo, Dem. Rep.', 'Africa', 2002, 44.966, 55379852,
#        241.16587650000002], dtype=object)

# %%
bd = (df['country'] == 'Bangladesh')

# %%
bangladesh = df.values[bd]

# %%
bangladesh
# Out:
# array([['Bangladesh', 'Asia', 1952, 37.484, 46886859, 684.2441716],
#        ['Bangladesh', 'Asia', 1957, 39.348, 51365468, 661.6374577],
#        ['Bangladesh', 'Asia', 1962, 41.216, 56839289, 686.3415537999999],
#        ['Bangladesh', 'Asia', 1967, 43.453, 62821884, 721.1860862000001],
#        ['Bangladesh', 'Asia', 1972, 45.251999999999995, 70759295,
#         630.2336265],
#        ['Bangladesh', 'Asia', 1977, 46.923, 80428306, 659.8772322000001],
#        ['Bangladesh', 'Asia', 1982, 50.00899999999999, 93074406,
#         676.9818656],
#        ['Bangladesh', 'Asia', 1987, 52.818999999999996, 103764241,
#         751.9794035],
#        ['Bangladesh', 'Asia', 1992, 56.018, 113704579, 837.8101642999999],
#        ['Bangladesh', 'Asia', 1997, 59.412, 123315288, 972.7700352],
#        ['Bangladesh', 'Asia', 2002, 62.013000000000005, 135656790,
#         1136.3904300000002],
#        ['Bangladesh', 'Asia', 2007, 64.062, 150448339, 1391.253792]],
#       dtype=object)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.loc[1]
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap        820.853
# Name: 1, dtype: object

# %%
dropped = df.drop(['continent'], axis= 'columns')
dropped
# Out:
#           country  year  lifeExp       pop   gdpPercap
# 0     Afghanistan  1952   28.801   8425333  779.445314
# 1     Afghanistan  1957   30.332   9240934  820.853030
# 2     Afghanistan  1962   31.997  10267083  853.100710
# 3     Afghanistan  1967   34.020  11537966  836.197138
# 4     Afghanistan  1972   36.088  13079460  739.981106
# ...           ...   ...      ...       ...         ...
# 1699     Zimbabwe  1987   62.351   9216418  706.157306
# 1700     Zimbabwe  1992   60.377  10704340  693.420786
# 1701     Zimbabwe  1997   46.809  11404948  792.449960
# 1702     Zimbabwe  2002   39.989  11926563  672.038623
# 1703     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[[1,2,3,4,]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.iloc[:,[2,1]]
# Out:
#       year continent
# 0     1952      Asia
# 1     1957      Asia
# 2     1962      Asia
# 3     1967      Asia
# 4     1972      Asia
# ...    ...       ...
# 1699  1987    Africa
# 1700  1992    Africa
# 1701  1997    Africa
# 1702  2002    Africa
# 1703  2007    Africa
#
# [1704 rows x 2 columns]

# %%
df.loc[:,['year','continent']]
# Out:
#       year continent
# 0     1952      Asia
# 1     1957      Asia
# 2     1962      Asia
# 3     1967      Asia
# 4     1972      Asia
# ...    ...       ...
# 1699  1987    Africa
# 1700  1992    Africa
# 1701  1997    Africa
# 1702  2002    Africa
# 1703  2007    Africa
#
# [1704 rows x 2 columns]

# %%
bde = df.loc[df['country'] == 'Bangladesh']

# %%
bde.values
# Out:
# array([['Bangladesh', 'Asia', 1952, 37.484, 46886859, 684.2441716],
#        ['Bangladesh', 'Asia', 1957, 39.348, 51365468, 661.6374577],
#        ['Bangladesh', 'Asia', 1962, 41.216, 56839289, 686.3415537999999],
#        ['Bangladesh', 'Asia', 1967, 43.453, 62821884, 721.1860862000001],
#        ['Bangladesh', 'Asia', 1972, 45.251999999999995, 70759295,
#         630.2336265],
#        ['Bangladesh', 'Asia', 1977, 46.923, 80428306, 659.8772322000001],
#        ['Bangladesh', 'Asia', 1982, 50.00899999999999, 93074406,
#         676.9818656],
#        ['Bangladesh', 'Asia', 1987, 52.818999999999996, 103764241,
#         751.9794035],
#        ['Bangladesh', 'Asia', 1992, 56.018, 113704579, 837.8101642999999],
#        ['Bangladesh', 'Asia', 1997, 59.412, 123315288, 972.7700352],
#        ['Bangladesh', 'Asia', 2002, 62.013000000000005, 135656790,
#         1136.3904300000002],
#        ['Bangladesh', 'Asia', 2007, 64.062, 150448339, 1391.253792]],
#       dtype=object)

# %%
bangladesh
# Out:
# array([['Bangladesh', 'Asia', 1952, 37.484, 46886859, 684.2441716],
#        ['Bangladesh', 'Asia', 1957, 39.348, 51365468, 661.6374577],
#        ['Bangladesh', 'Asia', 1962, 41.216, 56839289, 686.3415537999999],
#        ['Bangladesh', 'Asia', 1967, 43.453, 62821884, 721.1860862000001],
#        ['Bangladesh', 'Asia', 1972, 45.251999999999995, 70759295,
#         630.2336265],
#        ['Bangladesh', 'Asia', 1977, 46.923, 80428306, 659.8772322000001],
#        ['Bangladesh', 'Asia', 1982, 50.00899999999999, 93074406,
#         676.9818656],
#        ['Bangladesh', 'Asia', 1987, 52.818999999999996, 103764241,
#         751.9794035],
#        ['Bangladesh', 'Asia', 1992, 56.018, 113704579, 837.8101642999999],
#        ['Bangladesh', 'Asia', 1997, 59.412, 123315288, 972.7700352],
#        ['Bangladesh', 'Asia', 2002, 62.013000000000005, 135656790,
#         1136.3904300000002],
#        ['Bangladesh', 'Asia', 2007, 64.062, 150448339, 1391.253792]],
#       dtype=object)

# %%
bd = df.loc[(df['country'] == 'Bangladesh') & (df['year'] > 1990)]
bd
# Out:
#         country continent  year  lifeExp        pop    gdpPercap
# 104  Bangladesh      Asia  1992   56.018  113704579   837.810164
# 105  Bangladesh      Asia  1997   59.412  123315288   972.770035
# 106  Bangladesh      Asia  2002   62.013  135656790  1136.390430
# 107  Bangladesh      Asia  2007   64.062  150448339  1391.253792

# %%
df.groupby(['year'])['gdpPercap'].mean().plot()

# %%
df.groupby(['year','continent'])[['pop', 'gdpPercap']].agg(np.mean).reset_index()
# Out:
#     year continent           pop     gdpPercap
# 0   1952    Africa  4.570010e+06   1252.572466
# 1   1952  Americas  1.380610e+07   4079.062552
# 2   1952      Asia  4.228356e+07   5195.484004
# 3   1952    Europe  1.393736e+07   5661.057435
# 4   1952   Oceania  5.343003e+06  10298.085650
# 5   1957    Africa  5.093033e+06   1385.236062
# 6   1957  Americas  1.547816e+07   4616.043733
# 7   1957      Asia  4.735699e+07   5787.732940
# 8   1957    Europe  1.459635e+07   6963.012816
# 9   1957   Oceania  5.970988e+06  11598.522455
# 10  1962    Africa  5.702247e+06   1598.078825
# 11  1962  Americas  1.733081e+07   4901.541870
# 12  1962      Asia  5.140476e+07   5729.369625
# 13  1962    Europe  1.534517e+07   8365.486814
# 14  1962   Oceania  6.641759e+06  12696.452430
# 15  1967    Africa  6.447875e+06   2050.363801
# 16  1967  Americas  1.922986e+07   5668.253496
# 17  1967      Asia  5.774736e+07   5971.173374
# 18  1967    Europe  1.603930e+07  10143.823757
# ...
