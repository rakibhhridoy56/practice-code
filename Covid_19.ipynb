# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

# %%
covid_19 = pd.read_csv('covid_19_data.csv', index_col = 'ObservationDate')

covid_19['Deaths'].plot(figsize=(20,10), c='red')

# %%
covid_19 = pd.read_csv('covid_19_data.csv')
covid_19
# Out:
#        SNo ObservationDate Province/State                  Country/Region  \
# 0        1      01/22/2020          Anhui                  Mainland China
# 1        2      01/22/2020        Beijing                  Mainland China
# 2        3      01/22/2020      Chongqing                  Mainland China
# 3        4      01/22/2020         Fujian                  Mainland China
# 4        5      01/22/2020          Gansu                  Mainland China
# ...    ...             ...            ...                             ...
# 4930  4931        03/11/20    Mississippi                              US
# 4931  4932        03/11/20   North Dakota                              US
# 4932  4933        03/11/20  West Virginia                              US
# 4933  4934        03/11/20        Wyoming                              US
# 4934  4935        03/11/20            NaN  occupied Palestinian territory
#
#               Last Update  Confirmed  Deaths  Recovered
# ...

# %%
covid_19 = covid_19[['ObservationDate','Province/State','Country/Region','Last Update','Confirmed','Deaths','Recovered']]
bd = covid_19['Country/Region'] == 'Bangladesh'
covid_19[bd]
# Out:
#      ObservationDate Province/State Country/Region          Last Update  \
# 4126        03/08/20            NaN     Bangladesh  2020-03-08T10:53:02
# 4385        03/09/20            NaN     Bangladesh  2020-03-08T10:53:02
# 4658        03/10/20            NaN     Bangladesh  2020-03-10T06:19:32
# 4877        03/11/20            NaN     Bangladesh  2020-03-10T06:19:32
#
#       Confirmed  Deaths  Recovered
# 4126          3       0          0
# 4385          3       0          0
# 4658          3       0          0
# 4877          3       0          0

# %%
china = covid_19['Country/Region'] == 'Mainland China' 
covid_19[china][['Deaths','Confirmed','ObservationDate']][-10:]
# Out:
#       Deaths  Confirmed ObservationDate
# 4767       1        125        03/11/20
# 4771       1         93        03/11/20
# 4774       3         76        03/11/20
# 4775       1         75        03/11/20
# 4776       0         75        03/11/20
# 4819       0         18        03/11/20
# 4834       0         10        03/11/20
# 4902       0          1        03/11/20
# 4925       0          0        03/11/20
# 4926       0          0        03/11/20

# %%
india = covid_19['Country/Region'] == 'India'
covid_19[india]
# Out:
#      ObservationDate Province/State Country/Region          Last Update  \
# 430       01/30/2020            NaN          India        1/30/20 16:00
# 491       01/31/2020            NaN          India      1/31/2020 23:59
# 547         02/01/20            NaN          India       1/31/2020 8:15
# 607         02/02/20            NaN          India  2020-02-02T06:03:08
# 672         02/03/20            NaN          India  2020-02-03T21:43:02
# 740         02/04/20            NaN          India  2020-02-03T21:43:02
# 810         02/05/20            NaN          India  2020-02-03T21:43:02
# 881         02/06/20            NaN          India  2020-02-03T21:43:02
# 954         02/07/20            NaN          India  2020-02-03T21:43:02
# 1026        02/08/20            NaN          India  2020-02-03T21:43:02
# 1098        02/09/20            NaN          India  2020-02-03T21:43:02
# 1171        02/10/20            NaN          India  2020-02-03T21:43:02
# ...

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
covid_19['Deaths'].sum()
# Out:
# 87324

# %%
covid_19[china]
# Out:
#      ObservationDate Province/State  Country/Region          Last Update  \
# 0         01/22/2020          Anhui  Mainland China      1/22/2020 17:00
# 1         01/22/2020        Beijing  Mainland China      1/22/2020 17:00
# 2         01/22/2020      Chongqing  Mainland China      1/22/2020 17:00
# 3         01/22/2020         Fujian  Mainland China      1/22/2020 17:00
# 4         01/22/2020          Gansu  Mainland China      1/22/2020 17:00
# ...              ...            ...             ...                  ...
# 4819        03/11/20        Qinghai  Mainland China  2020-03-11T02:18:14
# 4834        03/11/20          Macau  Mainland China  2020-03-11T18:52:03
# 4902        03/11/20          Tibet  Mainland China  2020-03-11T02:18:14
# 4925        03/11/20          Gansu  Mainland China  2020-03-11T02:18:28
# 4926        03/11/20          Hebei  Mainland China  2020-03-11T02:18:29
#
#       Confirmed  Deaths  Recovered
# 0             1       0          0
# ...

# %%
china = covid_19[(covid_19['ObservationDate'] == '03/11/20') & (covid_19['Country/Region'] == 'Mainland China')]
china
# Out:
#      ObservationDate  Province/State  Country/Region          Last Update  \
# 4719        03/11/20           Hubei  Mainland China  2020-03-11T10:53:02
# 4726        03/11/20       Guangdong  Mainland China  2020-03-11T10:13:06
# 4727        03/11/20           Henan  Mainland China  2020-03-11T08:13:09
# 4728        03/11/20        Zhejiang  Mainland China  2020-03-11T09:33:12
# 4729        03/11/20           Hunan  Mainland China  2020-03-11T02:18:14
# 4730        03/11/20           Anhui  Mainland China  2020-03-11T02:18:14
# 4731        03/11/20         Jiangxi  Mainland China  2020-03-11T02:18:14
# 4732        03/11/20        Shandong  Mainland China  2020-03-11T11:33:07
# 4736        03/11/20         Jiangsu  Mainland China  2020-03-11T02:18:14
# 4738        03/11/20       Chongqing  Mainland China  2020-03-11T23:13:05
# 4739        03/11/20         Sichuan  Mainland China  2020-03-11T14:33:03
# 4742        03/11/20    Heilongjiang  Mainland China  2020-03-11T11:33:07
# ...

# %%
china
# Out:
#      ObservationDate  Province/State  Country/Region          Last Update  \
# 4719        03/11/20           Hubei  Mainland China  2020-03-11T10:53:02
# 4726        03/11/20       Guangdong  Mainland China  2020-03-11T10:13:06
# 4727        03/11/20           Henan  Mainland China  2020-03-11T08:13:09
# 4728        03/11/20        Zhejiang  Mainland China  2020-03-11T09:33:12
# 4729        03/11/20           Hunan  Mainland China  2020-03-11T02:18:14
# 4730        03/11/20           Anhui  Mainland China  2020-03-11T02:18:14
# 4731        03/11/20         Jiangxi  Mainland China  2020-03-11T02:18:14
# 4732        03/11/20        Shandong  Mainland China  2020-03-11T11:33:07
# 4736        03/11/20         Jiangsu  Mainland China  2020-03-11T02:18:14
# 4738        03/11/20       Chongqing  Mainland China  2020-03-11T23:13:05
# 4739        03/11/20         Sichuan  Mainland China  2020-03-11T14:33:03
# 4742        03/11/20    Heilongjiang  Mainland China  2020-03-11T11:33:07
# ...

# %%
china
# Out:
#      ObservationDate  Province/State  Country/Region          Last Update  \
# 4719        03/11/20           Hubei  Mainland China  2020-03-11T10:53:02
# 4726        03/11/20       Guangdong  Mainland China  2020-03-11T10:13:06
# 4727        03/11/20           Henan  Mainland China  2020-03-11T08:13:09
# 4728        03/11/20        Zhejiang  Mainland China  2020-03-11T09:33:12
# 4729        03/11/20           Hunan  Mainland China  2020-03-11T02:18:14
# 4730        03/11/20           Anhui  Mainland China  2020-03-11T02:18:14
# 4731        03/11/20         Jiangxi  Mainland China  2020-03-11T02:18:14
# 4732        03/11/20        Shandong  Mainland China  2020-03-11T11:33:07
# 4736        03/11/20         Jiangsu  Mainland China  2020-03-11T02:18:14
# 4738        03/11/20       Chongqing  Mainland China  2020-03-11T23:13:05
# 4739        03/11/20         Sichuan  Mainland China  2020-03-11T14:33:03
# 4742        03/11/20    Heilongjiang  Mainland China  2020-03-11T11:33:07
# ...

# %%
china['Deaths'][1:10].plot(kind='bar')

# %%
covid_19
# Out:
#      ObservationDate Province/State                  Country/Region  \
# 0         01/22/2020          Anhui                  Mainland China
# 1         01/22/2020        Beijing                  Mainland China
# 2         01/22/2020      Chongqing                  Mainland China
# 3         01/22/2020         Fujian                  Mainland China
# 4         01/22/2020          Gansu                  Mainland China
# ...              ...            ...                             ...
# 4930        03/11/20    Mississippi                              US
# 4931        03/11/20   North Dakota                              US
# 4932        03/11/20  West Virginia                              US
# 4933        03/11/20        Wyoming                              US
# 4934        03/11/20            NaN  occupied Palestinian territory
#
#               Last Update  Confirmed  Deaths  Recovered
# 0         1/22/2020 17:00          1       0          0
# ...

# %%
china['Deaths'].plot(c = 'red')

# %%
china
# Out:
#      ObservationDate  Province/State  Country/Region          Last Update  \
# 4719        03/11/20           Hubei  Mainland China  2020-03-11T10:53:02
# 4726        03/11/20       Guangdong  Mainland China  2020-03-11T10:13:06
# 4727        03/11/20           Henan  Mainland China  2020-03-11T08:13:09
# 4728        03/11/20        Zhejiang  Mainland China  2020-03-11T09:33:12
# 4729        03/11/20           Hunan  Mainland China  2020-03-11T02:18:14
# 4730        03/11/20           Anhui  Mainland China  2020-03-11T02:18:14
# 4731        03/11/20         Jiangxi  Mainland China  2020-03-11T02:18:14
# 4732        03/11/20        Shandong  Mainland China  2020-03-11T11:33:07
# 4736        03/11/20         Jiangsu  Mainland China  2020-03-11T02:18:14
# 4738        03/11/20       Chongqing  Mainland China  2020-03-11T23:13:05
# 4739        03/11/20         Sichuan  Mainland China  2020-03-11T14:33:03
# 4742        03/11/20    Heilongjiang  Mainland China  2020-03-11T11:33:07
# ...

# %%
china['Confirmed'][1:].plot(c='blue',figsize= (20,10))
plt.savefig('Confirmed Cases of China(without hubei).png')

# %%
line_list = pd.read_csv('line_list.csv')
line_list.columns
# Out:
# Index(['id', 'case_in_country', 'reporting date', 'Unnamed: 3', 'summary',
#        'location', 'country', 'gender', 'age', 'symptom_onset',
#        'If_onset_approximated', 'hosp_visit_date', 'exposure_start',
#        'exposure_end', 'visiting Wuhan', 'from Wuhan', 'death', 'recovered',
#        'symptom', 'source', 'link', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
ts_confirmed = pd.read_csv('time_series_covid_19_confirmed.csv')
ts_confirmed
# Out:
#        Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               Anhui  Mainland China  31.8257  117.2264        1        9
# 1             Beijing  Mainland China  40.1824  116.4142       14       22
# 2           Chongqing  Mainland China  30.0572  107.8740        6        9
# 3              Fujian  Mainland China  26.0789  117.9874        1        5
# 4               Gansu  Mainland China  36.0611  103.8343        0        2
# ..                ...             ...      ...       ...      ...      ...
# 399  Saint Barthelemy          France  17.9000  -62.8333        0        0
# 400               NaN         Jamaica  18.1096  -77.2975        0        0
# 401               NaN         Reunion -21.1151   55.5364        0        0
# 402               NaN          Turkey  38.9637   35.2433        0        0
# 403         Gibraltar  United Kingdom  36.1408   -5.3536        0        0
#
# ...

# %%
ts_deaths = pd.read_csv('time_series_covid_19_deaths.csv')
ts_deaths
# Out:
#        Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               Anhui  Mainland China  31.8257  117.2264        0        0
# 1             Beijing  Mainland China  40.1824  116.4142        0        0
# 2           Chongqing  Mainland China  30.0572  107.8740        0        0
# 3              Fujian  Mainland China  26.0789  117.9874        0        0
# 4               Gansu  Mainland China  36.0611  103.8343        0        0
# ..                ...             ...      ...       ...      ...      ...
# 399  Saint Barthelemy          France  17.9000  -62.8333        0        0
# 400               NaN         Jamaica  18.1096  -77.2975        0        0
# 401               NaN         Reunion -21.1151   55.5364        0        0
# 402               NaN          Turkey  38.9637   35.2433        0        0
# 403         Gibraltar  United Kingdom  36.1408   -5.3536        0        0
#
# ...

# %%
ts_recovered = pd.read_csv('time_series_covid_19_recovered.csv')
ts_recovered
# Out:
#        Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               Anhui  Mainland China  31.8257  117.2264        0        0
# 1             Beijing  Mainland China  40.1824  116.4142        0        0
# 2           Chongqing  Mainland China  30.0572  107.8740        0        0
# 3              Fujian  Mainland China  26.0789  117.9874        0        0
# 4               Gansu  Mainland China  36.0611  103.8343        0        0
# ..                ...             ...      ...       ...      ...      ...
# 399  Saint Barthelemy          France  17.9000  -62.8333        0        0
# 400               NaN         Jamaica  18.1096  -77.2975        0        0
# 401               NaN         Reunion -21.1151   55.5364        0        0
# 402               NaN          Turkey  38.9637   35.2433        0        0
# 403         Gibraltar  United Kingdom  36.1408   -5.3536        0        0
#
# ...

# %%
data = [Scattergeo(lon = ts_confirmed['Long'], lat = ts_confirmed['Lat'])]
ml = Layout(title= 'Confirmed Cases of Covid-19')
fig = {'data': data, 'layout' : ml}
offline.plot(fig, filename = 'Confirmed Cases of Covid-19.html')
# Out:
# 'Confirmed Cases of Covid-19.html'

# %%
ts_confirmed[['3/10/20','Country/Region']]
# Out:
#      3/10/20  Country/Region
# 0        990  Mainland China
# 1        429  Mainland China
# 2        576  Mainland China
# 3        296  Mainland China
# 4        125  Mainland China
# ..       ...             ...
# 399        0          France
# 400        0         Jamaica
# 401        0         Reunion
# 402        0          Turkey
# 403        0  United Kingdom
#
# [404 rows x 2 columns]

# %%
ts_confirmed
# Out:
#        Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               Anhui  Mainland China  31.8257  117.2264        1        9
# 1             Beijing  Mainland China  40.1824  116.4142       14       22
# 2           Chongqing  Mainland China  30.0572  107.8740        6        9
# 3              Fujian  Mainland China  26.0789  117.9874        1        5
# 4               Gansu  Mainland China  36.0611  103.8343        0        2
# ..                ...             ...      ...       ...      ...      ...
# 399  Saint Barthelemy          France  17.9000  -62.8333        0        0
# 400               NaN         Jamaica  18.1096  -77.2975        0        0
# 401               NaN         Reunion -21.1151   55.5364        0        0
# 402               NaN          Turkey  38.9637   35.2433        0        0
# 403         Gibraltar  United Kingdom  36.1408   -5.3536        0        0
#
# ...

# %%
turkey = ts_confirmed['Country/Region'] == 'Turkey'
ts_confirmed[turkey]
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 402            NaN         Turkey  38.9637  35.2433        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  \
# 402        0        0        0        0  ...       0       0       0       0
#
#      3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 402       0       0       0       0        0      1.0
#
# [1 rows x 54 columns]

# %%
ts_confirmed[390:]
# Out:
#        Province/State    Country/Region      Lat     Long  1/22/20  1/23/20  \
# 390               NaN           Bolivia -16.2902 -63.5887        0        0
# 391     Faroe Islands           Denmark  61.8926  -6.9118        0        0
# 392         St Martin            France  18.0708 -63.0501        0        0
# 393               NaN          Honduras  15.2000 -86.2419        0        0
# 394   Channel Islands    United Kingdom  49.3723  -2.3644        0        0
# 395     New Brunswick            Canada  46.5653 -66.4619        0        0
# 396             Tibet             China  31.6927  88.0924        0        0
# 397               NaN  Congo (Kinshasa)  -4.0383  21.7587        0        0
# 398               NaN     Cote d'Ivoire   7.5400  -5.5471        0        0
# 399  Saint Barthelemy            France  17.9000 -62.8333        0        0
# 400               NaN           Jamaica  18.1096 -77.2975        0        0
# ...

# %%
recovery_rate = ts_recovered['3/10/20'].sum() / ts_confirmed['3/10/20'].sum()
recovery_rate
# Out:
# 0.5398942189215694

# %%
deaths_rate = ts_deaths['3/10/20'].sum() / ts_confirmed['3/10/20'].sum()
deaths_rate
# Out:
# 0.03595886105127281

# %%
ts_confirmed['3/10/20'].plot()

# %%
china_confirmed = ts_confirmed['Country/Region'] == 'Mainland China'
china_confirmed = ts_confirmed[china_confirmed]

# %%
china_confirmed
# Out:
#     Province/State  Country/Region       Lat      Long  1/22/20  1/23/20  \
# 0            Anhui  Mainland China  31.82570  117.2264        1        9
# 1          Beijing  Mainland China  40.18240  116.4142       14       22
# 2        Chongqing  Mainland China  30.05720  107.8740        6        9
# 3           Fujian  Mainland China  26.07890  117.9874        1        5
# 4            Gansu  Mainland China  36.06110  103.8343        0        2
# 5        Guangdong  Mainland China  23.34170  113.4244       26       32
# 6          Guangxi  Mainland China  23.82980  108.7881        2        5
# 7          Guizhou  Mainland China  26.81540  106.8748        1        3
# 8           Hainan  Mainland China  19.19590  109.7453        4        5
# 9            Hebei  Mainland China  38.04280  114.5149        1        1
# 10    Heilongjiang  Mainland China  47.86200  127.7615        0        2
# 11           Henan  Mainland China  33.88202  113.6140        5        5
# ...

# %%
china_confirmed.set_index(china_confirmed['Province/State'], inplace= True)

# %%
china_confirmed['1/22/20'][:10].plot(figsize= (30,15), c= 'red', title = 'Confirmed Cases in January 22, 2020 || China')
china_confirmed['1/23/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/24/20'][:10].plot(figsize= (30,15), c= 'brown')
china_confirmed['1/25/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/26/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['1/27/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/28/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['1/29/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/30/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/1/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/2/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/3/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/4/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/5/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/6/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/7/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/8/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/9/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/10/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/11/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/12/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/13/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/14/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/15/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/16/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/17/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/18/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/19/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/20/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/21/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/22/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/23/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/24/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/25/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/26/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/27/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/28/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/29/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/1/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/2/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/3/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/4/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/5/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/6/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/7/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/8/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/9/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/10/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/11/20'][:10].plot(figsize= (30,15), c= 'red')

plt.savefig('Confirmed.png')

# %%
china_confirmed['1/22/20'][10:20].plot(figsize= (30,15), c= 'red', title = 'Confirmed Cases in January 22, 2020 || China')
china_confirmed['1/23/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/24/20'][10:20].plot(figsize= (30,15), c= 'brown')
china_confirmed['1/25/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/26/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['1/27/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/28/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['1/29/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['1/30/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/1/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/2/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/3/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/4/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/5/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/6/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/7/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/8/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/9/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/10/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/11/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/12/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/13/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/14/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/15/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/16/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/17/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/18/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/19/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/20/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/21/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/22/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/23/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/24/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/25/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/26/20'][10:20].plot(figsize= (30,15), c= 'red')
china_confirmed['2/27/20'][10:20].plot(figsize= (30,15), c= 'blue')
china_confirmed['2/28/20'][10:10].plot(figsize= (30,15), c= 'red')
china_confirmed['2/29/20'][10:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/1/20'][10:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/2/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/3/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/4/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/5/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/6/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/7/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/8/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/9/20'][:10].plot(figsize= (30,15), c= 'red')
china_confirmed['3/10/20'][:10].plot(figsize= (30,15), c= 'blue')
china_confirmed['3/11/20'][:10].plot(figsize= (30,15), c= 'red')

plt.savefig('Confirmed2.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d3c994eb5e92> in <module>
#      35 china_confirmed['2/26/20'][10:20].plot(figsize= (30,15), c= 'red')
#      36 china_confirmed['2/27/20'][10:20].plot(figsize= (30,15), c= 'blue')
# ---> 37 china_confirmed['2/28/20'][10:10].plot(figsize= (30,15), c= 'red')
#      38 china_confirmed['2/29/20'][10:10].plot(figsize= (30,15), c= 'blue')
#      39 china_confirmed['3/1/20'][10:10].plot(figsize= (30,15), c= 'red')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
ts_deaths['3/10/20'].sum()
# Out:
# 4290

# %%
ts_confirmed['3/10/20'].sum()
# Out:
# 119303

# %%
ts_recovered['3/10/20'].sum()
# Out:
# 64411

# %%
full_data = pd.read_csv('Covid_19_data.csv')
full_data
line_list = pd.read_csv('line_list.csv')
line_list['age']
# Out:
# 0       66.0
# 1       56.0
# 2       46.0
# 3       60.0
# 4       58.0
#         ...
# 1080    24.0
# 1081    35.0
# 1082     NaN
# 1083     NaN
# 1084    70.0
# Name: age, Length: 1085, dtype: float64

# %%
line_list['age'].min()
line_list['age'].max()
avg_deaths = line_list['age'].sum()/ len(line_list['age'])
print(f'The Average Age of Deaths in Covid-19 is {avg_deaths}')
# Out:
# The Average Age of Deaths in Covid-19 is 38.446774193548386

# %%
line_list
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
line_list.set_index('reporting date', inplace = True)

# %%
line_list['age'].plot(figsize = (20,10), title = 'Age Of Deaths In Covid-19', c= 'blue')
plt.savefig('AgeDeaths.png')

# %%
len(line_list['age'])
# Out:
# 1085

# %%
ages = []
for index,row in line_list.iterrows():
    age = row['age']
    
    ages.append(age)
ages[:10]
# Out:
# [66.0, 56.0, 46.0, 60.0, 58.0, 44.0, 34.0, 37.0, 39.0, 56.0]

# %%
ages_between_20_30 = []
for ia in ages:
    if ia > 20 and ia <30:
        ages_between_20_30.append(ia)

ages_between_20_30[:10]
# Out:
# [28.0, 29.0, 28.0, 23.0, 22.0, 29.0, 23.0, 29.0, 29.0, 24.0]

# %%
len(ages_between_20_30)
# Out:
# 93

# %%
1085/93
# Out:
# 11.666666666666666

# %%
import plotly.express as px
